# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib
# %matplotlib inline  
# %load_ext autoreload
# %autoreload 2
#matplotlib.rc('font', family='AppleGothic')

# %%
import userstudy_i2i_loader as X
lets = X.Userstudy(5)

# %%
lets.run()
# Out:
# Enter your name in englishpjw
# ...
# A 와 B 중 하나는 가짜 이미지 입니다. 아래의 질문에 답해주세요
# ...
# 어느것이 실제 이미지인가요?(A, B)	A
# ...
# A 와 B 중 하나는 가짜 이미지 입니다. 아래의 질문에 답해주세요
# ...
# 어느것이 실제 이미지인가요?(A, B)	B
# ...
# A 와 B 중 하나는 가짜 이미지 입니다. 아래의 질문에 답해주세요
# ...
# 어느것이 실제 이미지인가요?(A, B)	B
# ...
# A 와 B 중 하나는 가짜 이미지 입니다. 아래의 질문에 답해주세요
# ...
# 어느것이 실제 이미지인가요?(A, B)	A
# ...
# A 와 B 중 하나는 가짜 이미지 입니다. 아래의 질문에 답해주세요
# ...
# 어느것이 실제 이미지인가요?(A, B)	B
# ...
# Content 이미지에 style 이미지를 반영하여 변환한 이미지가 아래 A 와 B입니다. 아래의 질문에 답해주세요
# ...
# 어느것이 변환이 올바르게 되었나요?(A, B)?	A
# 어느것이 원본의 배경정보가 유지되고 있나요?(A, B)	A
# 어느것이 변환된 영역이 적절한가요?(A, B)	A
# ...
# Content 이미지에 style 이미지를 반영하여 변환한 이미지가 아래 A 와 B입니다. 아래의 질문에 답해주세요
# ...
# 어느것이 변환이 올바르게 되었나요?(A, B)?	B
# 어느것이 원본의 배경정보가 유지되고 있나요?(A, B)	B
# 어느것이 변환된 영역이 적절한가요?(A, B)	B
# ...
# Content 이미지에 style 이미지를 반영하여 변환한 이미지가 아래 A 와 B입니다. 아래의 질문에 답해주세요
# ...
# 어느것이 변환이 올바르게 되었나요?(A, B)?	B
# 어느것이 원본의 배경정보가 유지되고 있나요?(A, B)	B
# 어느것이 변환된 영역이 적절한가요?(A, B)	B
# ...
# Content 이미지에 style 이미지를 반영하여 변환한 이미지가 아래 A 와 B입니다. 아래의 질문에 답해주세요
# ...
# 어느것이 변환이 올바르게 되었나요?(A, B)?	B
# 어느것이 원본의 배경정보가 유지되고 있나요?(A, B)	B
# ...

# %%
lets.answer
# Out:
# {'pjw': {'Q1': {'correct_answer': [{'A': 'real', 'B': 'drit'},
#     {'A': 'real', 'B': 'ours'},
#     {'A': 'cdgan', 'B': 'real'},
#     {'A': 'munit', 'B': 'real'},
#     {'A': 'real', 'B': 'ours'}],
#    'user_answer': ['A', 'B', 'B', 'B', 'A']},
#   'Q2': {'correct_answer': [{'A': 'drit', 'B': 'ours'},
#     {'A': 'cdgan', 'B': 'ours'},
#     {'A': 'munit', 'B': 'ours'},
#     {'A': 'drit', 'B': 'ours'},
#     {'A': 'ours', 'B': 'drit'}],
#    'user_answer': ['B', 'B', 'B', 'B', 'B']},
#   'Q3': {'correct_answer': [{'A': 'drit', 'B': 'ours'},
#     {'A': 'cdgan', 'B': 'ours'},
#     {'A': 'munit', 'B': 'ours'},
#     {'A': 'drit', 'B': 'ours'},
#     {'A': 'ours', 'B': 'drit'}],
#    'user_answer': ['B', 'B', 'B', 'B', 'B']},
#   'Q4': {'correct_answer': [{'A': 'drit', 'B': 'ours'},
#     {'A': 'cdgan', 'B': 'ours'},
#     {'A': 'munit', 'B': 'ours'},
#     {'A': 'drit', 'B': 'ours'},
#     {'A': 'ours', 'B': 'drit'}],
#    'user_answer': ['B', 'B', 'B', 'B', 'B']}}}
