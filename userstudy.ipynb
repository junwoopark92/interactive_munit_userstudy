# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib
# %matplotlib inline  
# %load_ext autoreload
# %autoreload 2
#matplotlib.rc('font', family='AppleGothic')

# %%
import userstudy_i2i_loader as X
lets = X.Userstudy(5)

# %%
lets.run()
# Out:
# Enter your name in englishpjw
# ...
# A 와 B 중 하나는 가짜 이미지 입니다. 아래의 질문에 답해주세요
# ...
# 어느것이 실제 이미지인가요?(A, B)	A
# ...
# A 와 B 중 하나는 가짜 이미지 입니다. 아래의 질문에 답해주세요
# ...
# 어느것이 실제 이미지인가요?(A, B)	A
# ...
# A 와 B 중 하나는 가짜 이미지 입니다. 아래의 질문에 답해주세요
# ...
# 어느것이 실제 이미지인가요?(A, B)	A
# ...
# A 와 B 중 하나는 가짜 이미지 입니다. 아래의 질문에 답해주세요
# ...
# 어느것이 실제 이미지인가요?(A, B)	A
# ...
# A 와 B 중 하나는 가짜 이미지 입니다. 아래의 질문에 답해주세요
# ...
# 어느것이 실제 이미지인가요?(A, B)	A
# ...
# 갈색헤어 + 무표정인 이미지를 금색헤어 + 웃는 얼굴로 변환하는 학습모델입니다.
# 앞으로 말할 "스타일"의 의미는 style 이미지의 머리 색과 표정입니다.
# ...
# 어느 것이 스타일을 잘 적용했나요(A, B)?	A
# 어느 것이 content 이미지를 잘 유지하고 있나요(A, B)	A
# 어떤 이미지가 content의 배경정보를 잘 유지하고 있나요 (A, B)	A
# ...
# 갈색헤어 + 무표정인 이미지를 금색헤어 + 웃는 얼굴로 변환하는 학습모델입니다.
# 앞으로 말할 "스타일"의 의미는 style 이미지의 머리 색과 표정입니다.
# ...
# 어느 것이 스타일을 잘 적용했나요(A, B)?
# 어느 것이 content 이미지를 잘 유지하고 있나요(A, B)	A
# 어떤 이미지가 content의 배경정보를 잘 유지하고 있나요 (A, B)	A
# ...
# 갈색헤어 + 무표정인 이미지를 금색헤어 + 웃는 얼굴로 변환하는 학습모델입니다.
# 앞으로 말할 "스타일"의 의미는 style 이미지의 머리 색과 표정입니다.
# ...
# 어느 것이 스타일을 잘 적용했나요(A, B)?
# 어느 것이 content 이미지를 잘 유지하고 있나요(A, B)	A
# 어떤 이미지가 content의 배경정보를 잘 유지하고 있나요 (A, B)	A
# ...

# %%
lets.answer
# Out:
# {'pjw': {'Q1': {'correct_answer': [{'A': 'real', 'B': 'ours'},
#     {'A': 'drit', 'B': 'real'},
#     {'A': 'ours', 'B': 'real'},
#     {'A': 'munit', 'B': 'real'},
#     {'A': 'drit', 'B': 'real'}],
#    'user_answer': ['A', 'A', 'A', 'A', 'A']},
#   'Q2': {'correct_answer': [{'A': 'ours', 'B': 'drit'},
#     {'A': 'munit', 'B': 'ours'},
#     {'A': 'munit', 'B': 'ours'},
#     {'A': 'ours', 'B': 'drit'},
#     {'A': 'drit', 'B': 'ours'}],
#    'user_answer': ['A', '', '', 'A', 'A']},
#   'Q3': {'correct_answer': [{'A': 'ours', 'B': 'drit'},
#     {'A': 'munit', 'B': 'ours'},
#     {'A': 'munit', 'B': 'ours'},
#     {'A': 'ours', 'B': 'drit'},
#     {'A': 'drit', 'B': 'ours'}],
#    'user_answer': ['A', 'A', 'A', 'A', 'A']},
#   'Q4': {'correct_answer': [{'A': 'ours', 'B': 'drit'},
#     {'A': 'munit', 'B': 'ours'},
#     {'A': 'munit', 'B': 'ours'},
#     {'A': 'ours', 'B': 'drit'},
#     {'A': 'drit', 'B': 'ours'}],
#    'user_answer': ['A', 'A', 'A', 'A', 'A']}}}
